# %% [markdown]
# # 08A: Pandas
#
# Demonstrating common Pandas functionality

# %%
import pandas as pd

# %%
# creating a Pandas dataframe
data = {'color':['red','green','blue'],'rating':[1,2,3]}

df = pd.DataFrame(data)
print(df)
print("")

# to return a row in the df, use .loc and specify the index position
print(df.loc[0])
# Out:
#    color  rating
# 0    red       1
# 1  green       2
# 2   blue       3
#
# color     red
# rating      1
# Name: 0, dtype: object

# %%
# create an empty dataframe
df = pd.DataFrame()

# with just columns
df = pd.DataFrame(columns=['A','B','C','D','E'])
print(df)
print("")

# with just an index
df = pd.DataFrame(index=range(5))
print(df)
print("")

# take a copy and drop all rows
new_df = df[0:0]   # takes the structure of df but with zero rows
print(new_df)

# append data
data = [1,2,3,4,5]
df.append(data)
print(df)
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []
#
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]
#
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# reading a JSON string (additional)

# object has same format as a Python dictionary, with nesting
data = '{"colour":{"0":"red", "1":"green", "2":"blue"}, "rating": {"0":1,"1":2,"2":3}}'
df = pd.read_json(data)
print(df)
# Out:
#   colour  rating
# 0    red       1
# 1  green       2
# 2   blue       3

# %%
# using the JSON package (additional)
import requests
from pandas.io.json import json_normalize
import pandas as pd

url = "https://api.exchangerate-api.com/v4/latest/USD"
df = pd.read_json(url)
print(df)
# Out:
#                              provider  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ANG  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ZWL  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# AED  https://www.exchangerate-api.com/terms  USD 2022-01-21
# AFN  https://www.exchangerate-api.com/terms  USD 2022-01-21
# ALL  https://www.exchangerate-api.com/terms  USD 2022-01-21
# AMD  https://www.exchangerate-api.com/terms  USD 2022-01-21
# ANG  https://www.exchangerate-api.com/terms  USD 2022-01-21
# ..                                      ...  ...        ...
# XPF  https://www.exchangerate-api.com/terms  USD 2022-01-21
# YER  https://www.exchangerate-api.com/terms  USD 2022-01-21
# ZAR  https://www.exchangerate-api.com/terms  USD 2022-01-21
# ZMW  https://www.exchangerate-api.com/terms  USD 2022-01-21
# ZWL  https://www.exchangerate-api.com/terms  USD 2022-01-21
#
#      time_last_updated   rates
# AED         1642723202    3.67
# AFN         1642723202  105.00
# ALL         1642723202  107.42
# AMD         1642723202  481.46
# ANG         1642723202    1.79
# ..                 ...     ...
# XPF         1642723202  105.30
# YER         1642723202  250.46
# ZAR         1642723202   15.20
# ZMW         1642723202   17.41
# ZWL         1642723202  111.37
#
# [161 rows x 7 columns]

# %%
# write to csv file
data = [['Alise',32],['Bob',26],['Charlie',45]]
df = pd.DataFrame(data,columns=['Name','Age'])

df.to_csv('my_data.csv')

df.to_csv('my_data.csv',sep='\t', encoding='utf-8', index=False)

# %% [markdown]
# ## Inspecting dataframes
#
# First step should be to get a quick overview of the dataframe

# %%
# loading in simplified set of stats for London, as of 2013
df = pd.read_csv('LondonStats2013.csv')
print(df.head(3))
print(df.dtypes)
print(df.info)
print(df.describe)
print(df[0:3])
# Out:
#                         WardName   Wardcode  Pop2013  Aged0_15  Aged16_64  \
# 0                 City of London  E09000001     8000       600       6200
# 1   Barking and Dagenham - Abbey  E05000026    13650      3450       9550
# 2  Barking and Dagenham - Alibon  E05000027    10400      2700       6600
#
#    Aged65plus  PctBame  PctNotBornUK  MeanHousePrice2013  PctOpenSpace  ...  \
# 0        1200     21.4          36.7              595000       18.6425  ...
# 1         700     71.9          57.3              164000       19.6072  ...
# 2        1100     29.9          24.7              173500       22.4129  ...
#
#    AvgPubTransAccessibility11  CrimeRate1213  PopDensityKm2013  \
# 0                         7.6     730.789474       2538.062371
# 1                         5.7     164.400000      10500.000000
# 2                         3.2      83.900000       7428.600000
#
#    PctWithNoQual11  PctLev4Qual11  TurnoutMayoralElection12  Candidate  \
# 0              6.7           68.4                 48.523652      Boris
# 1             16.4           34.5                 25.688941        Ken
# 2             31.2           16.7                 20.347925        Ken
#
#              x            y  InnerOuter
# 0  532479.7201  181272.0253       Inner
# 1  544218.2356  184361.3980       Outer
# 2  549061.5648  185152.6226       Outer
#
# [3 rows x 21 columns]
# WardName                       object
# Wardcode                       object
# Pop2013                         int64
# Aged0_15                        int64
# Aged16_64                       int64
# Aged65plus                      int64
# PctBame                       float64
# PctNotBornUK                  float64
# MeanHousePrice2013              int64
# PctOpenSpace                  float64
# CarsPerHH2011                 float64
# AvgPubTransAccessibility11    float64
# CrimeRate1213                 float64
# PopDensityKm2013              float64
# PctWithNoQual11               float64
# PctLev4Qual11                 float64
# TurnoutMayoralElection12      float64
# Candidate                      object
# x                             float64
# y                             float64
# InnerOuter                     object
# dtype: object
# <bound method DataFrame.info of                                   WardName   Wardcode  Pop2013  Aged0_15  \
# 0                           City of London  E09000001     8000       600
# 1             Barking and Dagenham - Abbey  E05000026    13650      3450
# 2            Barking and Dagenham - Alibon  E05000027    10400      2700
# 3         Barking and Dagenham - Becontree  E05000028    12050      3000
# 4    Barking and Dagenham - Chadwell Heath  E05000029    10150      2450
# ..                                     ...        ...      ...       ...
# 620                Westminster - Tachbrook  E05000645     8300       900
# 621           Westminster - Vincent Square  E05000646    10300      1450
# 622                  Westminster - Warwick  E05000647     9550      1050
# 623               Westminster - Westbourne  E05000648    12950      2750
# 624                 Westminster - West End  E05000649    10950       950
#
#      Aged16_64  Aged65plus  PctBame  PctNotBornUK  MeanHousePrice2013  \
# 0         6200        1200     21.4          36.7              595000
# 1         9550         700     71.9          57.3              164000
# 2         6600        1100     29.9          24.7              173500
# 3         8000        1100     41.2          30.1              178995
# 4         6150        1550     37.9          24.8              210000
# ..         ...         ...      ...           ...                 ...
# 620       6150        1250     21.8          41.1              540000
# 621       7500        1300     29.3          44.6              682500
# 622       7350        1150     24.0          43.9              766000
# 623       9050        1200     52.8          51.5              432500
# 624       8800        1200     32.4          56.8             1617500
#
#      PctOpenSpace  ...  AvgPubTransAccessibility11  CrimeRate1213  \
# 0        18.64250  ...                         7.6     730.789474
# 1        19.60720  ...                         5.7     164.400000
# 2        22.41290  ...                         3.2      83.900000
# 3         3.03888  ...                         2.9      85.700000
# 4        56.40730  ...                         2.2      84.500000
# ..            ...  ...                         ...            ...
# 620      32.36900  ...                         6.1      59.000000
# 621      30.03720  ...                         6.8      98.600000
# 622       4.02236  ...                         6.3     176.500000
# 623      19.23940  ...                         4.8      89.700000
# 624       3.86991  ...                         8.0    1798.900000
#
#      PopDensityKm2013  PctWithNoQual11  PctLev4Qual11  \
# 0         2538.062371              6.7           68.4
# 1        10500.000000             16.4           34.5
# 2         7428.600000             31.2           16.7
# 3         9269.200000             28.0           20.6
# 4         2985.300000             29.1           19.5
# ..                ...              ...            ...
# 620      20750.000000             12.5           55.1
# 621      14714.300000             11.7           53.1
# 622      15916.700000              9.4           58.5
# 623      18500.000000             22.4           35.7
# 624       5475.000000              9.6           54.6
#
#      TurnoutMayoralElection12  Candidate            x            y  InnerOuter
# 0                   48.523652      Boris  532479.7201  181272.0253       Inner
# 1                   25.688941        Ken  544218.2356  184361.3980       Outer
# 2                   20.347925        Ken  549061.5648  185152.6226       Outer
# 3                   22.538211        Ken  546997.5893  186088.9148       Outer
# 4                   25.318814        Ken  548358.8573  189491.7100       Outer
# ..                        ...        ...          ...          ...         ...
# 620                 40.184280      Boris  529591.4402  178259.5661       Inner
# 621                 37.832480      Boris  529719.1279  178793.7703       Inner
# 622                 36.842105      Boris  528952.5360  178655.3201       Inner
# 623                 29.550731        Ken  525414.5440  181807.3312       Inner
# 624                 29.665242      Boris  528919.3839  180901.9990       Inner
#
# [625 rows x 21 columns]>
# <bound method NDFrame.describe of                                   WardName   Wardcode  Pop2013  Aged0_15  \
# 0                           City of London  E09000001     8000       600
# 1             Barking and Dagenham - Abbey  E05000026    13650      3450
# 2            Barking and Dagenham - Alibon  E05000027    10400      2700
# 3         Barking and Dagenham - Becontree  E05000028    12050      3000
# 4    Barking and Dagenham - Chadwell Heath  E05000029    10150      2450
# ..                                     ...        ...      ...       ...
# 620                Westminster - Tachbrook  E05000645     8300       900
# 621           Westminster - Vincent Square  E05000646    10300      1450
# 622                  Westminster - Warwick  E05000647     9550      1050
# 623               Westminster - Westbourne  E05000648    12950      2750
# 624                 Westminster - West End  E05000649    10950       950
#
#      Aged16_64  Aged65plus  PctBame  PctNotBornUK  MeanHousePrice2013  \
# 0         6200        1200     21.4          36.7              595000
# 1         9550         700     71.9          57.3              164000
# 2         6600        1100     29.9          24.7              173500
# 3         8000        1100     41.2          30.1              178995
# 4         6150        1550     37.9          24.8              210000
# ..         ...         ...      ...           ...                 ...
# 620       6150        1250     21.8          41.1              540000
# 621       7500        1300     29.3          44.6              682500
# 622       7350        1150     24.0          43.9              766000
# 623       9050        1200     52.8          51.5              432500
# 624       8800        1200     32.4          56.8             1617500
#
#      PctOpenSpace  ...  AvgPubTransAccessibility11  CrimeRate1213  \
# 0        18.64250  ...                         7.6     730.789474
# 1        19.60720  ...                         5.7     164.400000
# 2        22.41290  ...                         3.2      83.900000
# 3         3.03888  ...                         2.9      85.700000
# 4        56.40730  ...                         2.2      84.500000
# ..            ...  ...                         ...            ...
# 620      32.36900  ...                         6.1      59.000000
# 621      30.03720  ...                         6.8      98.600000
# 622       4.02236  ...                         6.3     176.500000
# 623      19.23940  ...                         4.8      89.700000
# 624       3.86991  ...                         8.0    1798.900000
#
#      PopDensityKm2013  PctWithNoQual11  PctLev4Qual11  \
# 0         2538.062371              6.7           68.4
# 1        10500.000000             16.4           34.5
# 2         7428.600000             31.2           16.7
# 3         9269.200000             28.0           20.6
# 4         2985.300000             29.1           19.5
# ..                ...              ...            ...
# 620      20750.000000             12.5           55.1
# 621      14714.300000             11.7           53.1
# 622      15916.700000              9.4           58.5
# 623      18500.000000             22.4           35.7
# 624       5475.000000              9.6           54.6
#
#      TurnoutMayoralElection12  Candidate            x            y  InnerOuter
# 0                   48.523652      Boris  532479.7201  181272.0253       Inner
# 1                   25.688941        Ken  544218.2356  184361.3980       Outer
# 2                   20.347925        Ken  549061.5648  185152.6226       Outer
# 3                   22.538211        Ken  546997.5893  186088.9148       Outer
# 4                   25.318814        Ken  548358.8573  189491.7100       Outer
# ..                        ...        ...          ...          ...         ...
# 620                 40.184280      Boris  529591.4402  178259.5661       Inner
# 621                 37.832480      Boris  529719.1279  178793.7703       Inner
# 622                 36.842105      Boris  528952.5360  178655.3201       Inner
# 623                 29.550731        Ken  525414.5440  181807.3312       Inner
# 624                 29.665242      Boris  528919.3839  180901.9990       Inner
#
# [625 rows x 21 columns]>
#                         WardName   Wardcode  Pop2013  Aged0_15  Aged16_64  \
# 0                 City of London  E09000001     8000       600       6200
# 1   Barking and Dagenham - Abbey  E05000026    13650      3450       9550
# 2  Barking and Dagenham - Alibon  E05000027    10400      2700       6600
#
#    Aged65plus  PctBame  PctNotBornUK  MeanHousePrice2013  PctOpenSpace  ...  \
# 0        1200     21.4          36.7              595000       18.6425  ...
# 1         700     71.9          57.3              164000       19.6072  ...
# 2        1100     29.9          24.7              173500       22.4129  ...
#
#    AvgPubTransAccessibility11  CrimeRate1213  PopDensityKm2013  \
# 0                         7.6     730.789474       2538.062371
# 1                         5.7     164.400000      10500.000000
# 2                         3.2      83.900000       7428.600000
#
#    PctWithNoQual11  PctLev4Qual11  TurnoutMayoralElection12  Candidate  \
# 0              6.7           68.4                 48.523652      Boris
# 1             16.4           34.5                 25.688941        Ken
# 2             31.2           16.7                 20.347925        Ken
#
#              x            y  InnerOuter
# 0  532479.7201  181272.0253       Inner
# 1  544218.2356  184361.3980       Outer
# 2  549061.5648  185152.6226       Outer
#
# [3 rows x 21 columns]

# %%
# standard descriptive statistics that can be applied to any column (additional)
print(df['PctOpenSpace'].count())
print(df['PctOpenSpace'].sum())
print(df['PctOpenSpace'].mean())
print(df['PctOpenSpace'].min())
print(df['PctOpenSpace'].max())
# Out:
# 625
# 16953.541185
# 27.125665895999997
# 0.0
# 88.8026
