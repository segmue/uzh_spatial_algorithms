# %% [markdown]
# # 05: Importing scripts
#
# Showing the different ways for importing and referencing packages and custom scripts
#
# Package = installed package (will contain multiple scripts, must be installed to use)
#
# Custom script = script stored within the same folder as this script

# %%
# different ways to import libraries & demonstrating different import methods
import numpy
print(numpy.sqrt(9))

import numpy as np
print(np.sqrt(9))

from numpy import sqrt
print(sqrt(9))

from numpy import *
# Out:
# 3.0
# 3.0
# 3.0

# %%
# calling a user-defined function (view script my_functions.py) (Additional example)
from my_functions import *

x = addTax(5)
print(x)
# Out:
# 5.4
